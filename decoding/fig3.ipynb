# %%
# %matplotlib inline

# %%
from decoder_aux import collect_all_data, collect_all_data_final
from plot import plot_all

# %%
cache_file = 'fig3.hdf5'
data_collect_dict = collect_all_data(cache_file, False)
# Out:
# data stat mean 0.03, std 0.10, min -0.90, max 3.23
# A NearestCentroid None no_thresh None
# data stat mean 0.03, std 0.10, min -0.90, max 3.23
# A NearestCentroid zerofill thresh_percentile 1
# A NearestCentroid zerofill thresh_percentile 10
# A NearestCentroid zerofill thresh_percentile 20
# A NearestCentroid zerofill thresh_percentile 30
# A NearestCentroid zerofill thresh_percentile 40
# A NearestCentroid zerofill thresh_percentile 50
# A NearestCentroid zerofill thresh_percentile 60
# A NearestCentroid zerofill thresh_percentile 70
# A NearestCentroid zerofill thresh_percentile 80
# A NearestCentroid zerofill thresh_percentile 90
# A NearestCentroid zerofill thresh_percentile 91
# A NearestCentroid zerofill thresh_percentile 92
# A NearestCentroid zerofill thresh_percentile 93
# A NearestCentroid zerofill thresh_percentile 94
# A NearestCentroid zerofill thresh_percentile 95
# A NearestCentroid zerofill thresh_percentile 96
# A NearestCentroid zerofill thresh_percentile 97
# ...

# %%
final_result = collect_all_data_final(data_collect_dict)

# %%
final_result
# Out:
# OrderedDict([('A',
#               OrderedDict([('acc_default', 0.54103703703703698),
#                            ('fills',
#                             OrderedDict([('zerofill',
#                                           {'acc_above': array([  5.51851852e-01,   5.50518519e-01,   5.48148148e-01,
#                                                     5.48740741e-01,   5.48740741e-01,   5.46666667e-01,
#                                                     5.40296296e-01,   5.24444444e-01,   4.98962963e-01,
#                                                     4.57333333e-01,   4.52888889e-01,   4.47407407e-01,
#                                                     4.38074074e-01,   4.38222222e-01,   4.31407407e-01,
#                                                     4.23703704e-01,   4.11851852e-01,   3.97037037e-01,
#                                                     3.55111111e-01,   3.46518519e-01,   3.38962963e-01,
# ...

# %%
plot_all(final_result)
